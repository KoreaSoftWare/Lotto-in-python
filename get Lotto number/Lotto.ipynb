# %%
# %matplotlib nbagg
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

Lotto_number = pd.read_excel("Lotto_number_count.xlsx")

Lotto_number.plot(kind = "barh")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
import pandas as pd

Lotto_number = pd.read_excel("Lotto_number_count.xlsx")

Lotto_number
# Out:
#       1   2   3   4   5    6   BONUS
# 0   131   0   0   0   0    0      27
# 1   103  19   0   0   0    0      26
# 2    91  31   3   0   0    0      23
# 3    85  38   4   0   0    0      28
# 4    81  41   5   1   0    0      17
# 5    69  35  11   3   0    0      27
# 6    58  56  10   0   0    0      21
# 7    46  59  17   3   0    0      18
# 8    32  45  13   4   1    0      21
# 9    37  60  29   1   1    0      22
# 10   33  52  29  12   0    0      20
# 11   31  53  34  13   2    0      23
# 12   23  43  50  12   2    0      26
# 13   27  44  41  19   1    0      18
# 14   11  49  41  22   3    0      16
# 15   21  33  38  26   3    0      24
# 16   15  42  44  27   7    0      25
# 17    7  39  53  28   8    0      15
# 18   12  26  52  25  11    3      17
# 19    4  27  53  28  15    4      22
# 20    5  25  38  40  14    3      21
# 21    3  20  36  29  14    3      14
# 22    3  18  32  38  18    4      17
# 23    2  14  38  44  23    2      23
# ...

# %%
import pandas as pd

class Lotto :
    Lotto_number = pd.DataFrame()
            
    def __init__(self, Lotto_number):
        self.Lotto_number = Lotto_number
    
    def main(self):
        self.GetLottoNumber()
        
    
    def GetLottoNumber(self):
        for i in self.Lotto_number.columns:
            print(int(self.Lotto_number[i].argmax()) + 1, end=" ")
            
Lotto_number = pd.read_excel("Lotto_number_count.xlsx")

Lotto = Lotto(Lotto_number)

Lotto.main()
# Out:
# 1 10 18 26 34 45 43
